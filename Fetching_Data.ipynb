# %% [markdown]
# # Helpers and things I have created for fetching hex maze data

# %%
import spyglass.common as sgc
import spyglass.position as sgp
import spyglass.data_import as sgi

from hexmaze import plot_hex_maze
from hex_maze_behavior import HexMazeBlock, HexPosition, HexPath, HexMazeChoice

# %% [markdown]
# ## Fetch data from `HexMazeBlock` and `HexMazeBlock.Trial` tables
#
# Both of these tables have the secondary key `interval_list_name`, so we can't do a regular join using `*`.
#
# I have a function `HexMazeBlock().join_with_trial()` that automatically renames these to `block_interval_list_name` and `trial_interval_list_name` so we can join them

# %%
from hex_maze_behavior import HexMazeBlock

# block table
display(HexMazeBlock())

# trial table
display(HexMazeBlock.Trial())

# block + trial table !
display(HexMazeBlock().join_with_trial())
# Out:
# *nwb_file_name *epoch    *block    config_id      interval_list_ p_a      p_b      p_c      num_trials     task_type
# +------------+ +-------+ +-------+ +------------+ +------------+ +------+ +------+ +------+ +------------+ +------------+
# BraveLu2024051 1         1         9,10,20,21,23, epoch1_block1  10.0     50.0     90.0     69             probability ch
# BraveLu2024051 1         2         9,10,20,21,23, epoch1_block2  90.0     10.0     50.0     69             probability ch
# BraveLu2024051 1         3         9,10,20,21,23, epoch1_block3  10.0     90.0     50.0     69             probability ch
# BraveLu2024051 3         1         9,10,18,19,21, epoch3_block1  90.0     50.0     10.0     69             probability ch
# BraveLu2024051 3         2         9,10,18,19,21, epoch3_block2  50.0     10.0     90.0     69             probability ch
# BraveLu2024051 3         3         9,10,18,19,21, epoch3_block3  10.0     90.0     50.0     69             probability ch
# BraveLu2024051 5         1         9,11,16,21,29, epoch5_block1  50.0     90.0     10.0     43             barrier change
# BraveLu2024051 5         2         9,11,14,21,29, epoch5_block2  50.0     90.0     10.0     64             barrier change
# BraveLu2024051 5         3         9,11,14,20,21, epoch5_block3  50.0     90.0     10.0     32             barrier change
# BraveLu2024051 7         1         7,11,12,20,26, epoch7_block1  10.0     50.0     90.0     72             barrier change
# BraveLu2024051 7         2         7,11,12,14,20, epoch7_block2  10.0     50.0     90.0     28             barrier change
# BraveLu2024051 7         3         7,11,14,20,26, epoch7_block3  10.0     50.0     90.0     64             barrier change
#    ...
#  (Total: 94)
# *nwb_file_name *epoch    *block    *block_trial_n interval_list_ epoch_trial_nu reward     start_port     end_port     opto_cond     poke_inter duration
# +------------+ +-------+ +-------+ +------------+ +------------+ +------------+ +--------+ +------------+ +----------+ +-----------+ +--------+ +----------+
# BraveLu2024051 1         1         1              epoch1_block1_ 1              1          None           B            no_delay      =BLOB=     11.2154
# BraveLu2024051 1         1         2              epoch1_block1_ 2              0          B              A            None          =BLOB=     22.473
# BraveLu2024051 1         1         3              epoch1_block1_ 3              1          A              B            delay         =BLOB=     21.1646
# BraveLu2024051 1         1         4              epoch1_block1_ 4              1          B              A            delay         =BLOB=     21.8469
# BraveLu2024051 1         1         5              epoch1_block1_ 5              0          A              B            None          =BLOB=     7.79641
# BraveLu2024051 1         1         6              epoch1_block1_ 6              0          B              A            None          =BLOB=     7.17867
# BraveLu2024051 1         1         7              epoch1_block1_ 7              0          A              B            None          =BLOB=     9.66421
# BraveLu2024051 1         1         8              epoch1_block1_ 8              0          B              A            None          =BLOB=     7.85081
# BraveLu2024051 1         1         9              epoch1_block1_ 9              1          A              B            delay         =BLOB=     17.3832
# BraveLu2024051 1         1         10             epoch1_block1_ 10             0          B              A            None          =BLOB=     8.07304
# BraveLu2024051 1         1         11             epoch1_block1_ 11             0          A              B            None          =BLOB=     10.9791
# BraveLu2024051 1         1         12             epoch1_block1_ 12             0          B              A            None          =BLOB=     8.73221
#    ...
#  (Total: 5125)
# *nwb_file_name *epoch    *block    *block_trial_n config_id      block_interval p_a      p_b      p_c      num_trials     task_type      trial_interval epoch_trial_nu reward     start_port     end_port     opto_cond     poke_inter duration
# +------------+ +-------+ +-------+ +------------+ +------------+ +------------+ +------+ +------+ +------+ +------------+ +------------+ +------------+ +------------+ +--------+ +------------+ +----------+ +-----------+ +--------+ +----------+
# BraveLu2024051 1         1         1              9,10,20,21,23, epoch1_block1  10.0     50.0     90.0     69             probability ch epoch1_block1_ 1              1          None           B            no_delay      =BLOB=     11.2154
# BraveLu2024051 1         1         2              9,10,20,21,23, epoch1_block1  10.0     50.0     90.0     69             probability ch epoch1_block1_ 2              0          B              A            None          =BLOB=     22.473
# BraveLu2024051 1         1         3              9,10,20,21,23, epoch1_block1  10.0     50.0     90.0     69             probability ch epoch1_block1_ 3              1          A              B            delay         =BLOB=     21.1646
# BraveLu2024051 1         1         4              9,10,20,21,23, epoch1_block1  10.0     50.0     90.0     69             probability ch epoch1_block1_ 4              1          B              A            delay         =BLOB=     21.8469
# BraveLu2024051 1         1         5              9,10,20,21,23, epoch1_block1  10.0     50.0     90.0     69             probability ch epoch1_block1_ 5              0          A              B            None          =BLOB=     7.79641
# BraveLu2024051 1         1         6              9,10,20,21,23, epoch1_block1  10.0     50.0     90.0     69             probability ch epoch1_block1_ 6              0          B              A            None          =BLOB=     7.17867
# BraveLu2024051 1         1         7              9,10,20,21,23, epoch1_block1  10.0     50.0     90.0     69             probability ch epoch1_block1_ 7              0          A              B            None          =BLOB=     9.66421
# BraveLu2024051 1         1         8              9,10,20,21,23, epoch1_block1  10.0     50.0     90.0     69             probability ch epoch1_block1_ 8              0          B              A            None          =BLOB=     7.85081
# BraveLu2024051 1         1         9              9,10,20,21,23, epoch1_block1  10.0     50.0     90.0     69             probability ch epoch1_block1_ 9              1          A              B            delay         =BLOB=     17.3832
# BraveLu2024051 1         1         10             9,10,20,21,23, epoch1_block1  10.0     50.0     90.0     69             probability ch epoch1_block1_ 10             0          B              A            None          =BLOB=     8.07304
# BraveLu2024051 1         1         11             9,10,20,21,23, epoch1_block1  10.0     50.0     90.0     69             probability ch epoch1_block1_ 11             0          A              B            None          =BLOB=     10.9791
# BraveLu2024051 1         1         12             9,10,20,21,23, epoch1_block1  10.0     50.0     90.0     69             probability ch epoch1_block1_ 12             0          B              A            None          =BLOB=     8.73221
#    ...
#  (Total: 5125)

# %% [markdown]
# ## Fetch choice data for each trial from the `HexMazeChoice` table
#
# There is one entry in the `HexMazeChoice` table per trial, excluding the first trial in each epoch because there is no start port, so no choice direction

# %%
from hex_maze_behavior import HexMazeBlock, HexMazeChoice

# See HexMazeChoice
display(HexMazeChoice())

# And we can join it with the trial table too! Or the block table, etc etc
display(HexMazeChoice() * HexMazeBlock.Trial())
# Out:
# *nwb_file_name *epoch    *block    *block_trial_n choice_directi reward_prob_di path_length_di
# +------------+ +-------+ +-------+ +------------+ +------------+ +------------+ +------------+
# BraveLu2024051 1         1         2              left           -80.0          -8.0
# BraveLu2024051 1         1         3              right          -40.0          -2.0
# BraveLu2024051 1         1         4              left           -80.0          -8.0
# BraveLu2024051 1         1         5              right          -40.0          -2.0
# BraveLu2024051 1         1         6              left           -80.0          -8.0
# BraveLu2024051 1         1         7              right          -40.0          -2.0
# BraveLu2024051 1         1         8              left           -80.0          -8.0
# BraveLu2024051 1         1         9              right          -40.0          -2.0
# BraveLu2024051 1         1         10             left           -80.0          -8.0
# BraveLu2024051 1         1         11             right          -40.0          -2.0
# BraveLu2024051 1         1         12             left           -80.0          -8.0
# BraveLu2024051 1         1         13             right          -40.0          -2.0
#    ...
#  (Total: 5101)
# *nwb_file_name *epoch    *block    *block_trial_n choice_directi reward_prob_di path_length_di interval_list_ epoch_trial_nu reward     start_port     end_port     opto_cond     poke_inter duration
# +------------+ +-------+ +-------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +------------+ +----------+ +-----------+ +--------+ +----------+
# BraveLu2024051 1         1         2              left           -80.0          -8.0           epoch1_block1_ 2              0          B              A            None          =BLOB=     22.473
# BraveLu2024051 1         1         3              right          -40.0          -2.0           epoch1_block1_ 3              1          A              B            delay         =BLOB=     21.1646
# BraveLu2024051 1         1         4              left           -80.0          -8.0           epoch1_block1_ 4              1          B              A            delay         =BLOB=     21.8469
# BraveLu2024051 1         1         5              right          -40.0          -2.0           epoch1_block1_ 5              0          A              B            None          =BLOB=     7.79641
# BraveLu2024051 1         1         6              left           -80.0          -8.0           epoch1_block1_ 6              0          B              A            None          =BLOB=     7.17867
# BraveLu2024051 1         1         7              right          -40.0          -2.0           epoch1_block1_ 7              0          A              B            None          =BLOB=     9.66421
# BraveLu2024051 1         1         8              left           -80.0          -8.0           epoch1_block1_ 8              0          B              A            None          =BLOB=     7.85081
# BraveLu2024051 1         1         9              right          -40.0          -2.0           epoch1_block1_ 9              1          A              B            delay         =BLOB=     17.3832
# BraveLu2024051 1         1         10             left           -80.0          -8.0           epoch1_block1_ 10             0          B              A            None          =BLOB=     8.07304
# BraveLu2024051 1         1         11             right          -40.0          -2.0           epoch1_block1_ 11             0          A              B            None          =BLOB=     10.9791
# BraveLu2024051 1         1         12             left           -80.0          -8.0           epoch1_block1_ 12             0          B              A            None          =BLOB=     8.73221
# BraveLu2024051 1         1         13             right          -40.0          -2.0           epoch1_block1_ 13             0          A              B            None          =BLOB=     7.11297
#    ...
#  (Total: 5101)

# %% [markdown]
# ## Fetch data from the `HexPath` table

# %%
# Example of fetching data from HexPath table
hex_path_key = {"pos_merge_id": "4eeb7432-969b-f856-3cfb-dd4456754ac4"}
display(HexPath() & hex_path_key)

# Get hex path dataframe for the whole epoch
epoch_df = (HexPath & hex_path_key).fetch1_dataframe()
display(epoch_df)

# Get hex path dataframe for a specific block
block_df = (HexPath & hex_path_key).fetch_block(block=1)
display(block_df)

# Get hex path dataframe for a specific trial
trial_df = (HexPath & hex_path_key).fetch_trial(block=1, block_trial_num=10)
display(trial_df)

# Get hex path dataframe for a range of trials (here, trials 1-3 for all blocks)
trials_df = (HexPath & hex_path_key).fetch_trials(block_trial_num=[1, 2, 3])
display(trials_df)
# Out:
# *pos_merge_id  *nwb_file_name *epoch    analysis_file_ hex_path_objec
# +------------+ +------------+ +-------+ +------------+ +------------+
# 4eeb7432-969b- Toby20250316_. 1         Toby20250316_P 8cf73764-604e-
#  (Total: 1)
#       block  block_trial_num  hex    entry_time     exit_time   duration  \
# id
# 0         1                1    1  1.742151e+09  1.742151e+09   1.403194
# 1         1                1   38  1.742151e+09  1.742151e+09   0.374185
# 2         1                1   49  1.742151e+09  1.742151e+09   0.249450
# 3         1                1    2  1.742151e+09  1.742151e+09   6.641766
# 4         1                2    2  1.742151e+09  1.742151e+09  17.586658
# ...     ...              ...  ...           ...           ...        ...
# 4385      3               69   11  1.742154e+09  1.742154e+09   0.218282
# 4386      3               69    8  1.742154e+09  1.742154e+09   0.124715
# 4387      3               69    6  1.742154e+09  1.742154e+09   0.187093
# 4388      3               69    4  1.742154e+09  1.742154e+09   0.093546
# 4389      3               69    1  1.742154e+09  1.742154e+09   8.387957
#
#       hex_in_trial  hex_entry_num  hexes_from_start  hexes_from_end hex_type  \
# id
# 0                1              1                -1              22  optimal
# 1                2              1                -1               2  optimal
# 2                3              1                -1               1  optimal
# 3                4              1                -1               0  optimal
# 4                1              1                 0              22  optimal
# ...            ...            ...               ...             ...      ...
# 4385            21              1                18               4  optimal
# 4386            22              1                19               3  optimal
# 4387            23              1                20               2  optimal
# 4388            24              1                21               1  optimal
# 4389            25              1                22               0  optimal
#
#      maze_portion
# id
# 0            None
# 1          chosen
# 2          chosen
# 3          chosen
# 4           start
# ...           ...
# 4385       chosen
# 4386       chosen
# 4387       chosen
# 4388       chosen
# 4389       chosen
#
# [4390 rows x 12 columns]
#       block  block_trial_num  hex    entry_time     exit_time   duration  \
# 0         1                1    1  1.742151e+09  1.742151e+09   1.403194
# 1         1                1   38  1.742151e+09  1.742151e+09   0.374185
# 2         1                1   49  1.742151e+09  1.742151e+09   0.249450
# 3         1                1    2  1.742151e+09  1.742151e+09   6.641766
# 4         1                2    2  1.742151e+09  1.742151e+09  17.586658
# ...     ...              ...  ...           ...           ...        ...
# 1661      1               69   11  1.742153e+09  1.742153e+09   0.218281
# 1662      1               69    8  1.742153e+09  1.742153e+09   0.124735
# 1663      1               69    6  1.742153e+09  1.742153e+09   0.155904
# 1664      1               69    4  1.742153e+09  1.742153e+09   0.093546
# 1665      1               69    1  1.742153e+09  1.742153e+09   2.089206
#
#       hex_in_trial  hex_entry_num  hexes_from_start  hexes_from_end hex_type  \
# 0                1              1                -1              22  optimal
# 1                2              1                -1               2  optimal
# 2                3              1                -1               1  optimal
# 3                4              1                -1               0  optimal
# 4                1              1                 0              22  optimal
# ...            ...            ...               ...             ...      ...
# 1661            19              1                18               4  optimal
# 1662            20              1                19               3  optimal
# 1663            21              1                20               2  optimal
# 1664            22              1                21               1  optimal
# 1665            23              1                22               0  optimal
#
#      maze_portion
# 0            None
# 1          chosen
# 2          chosen
# 3          chosen
# 4           start
# ...           ...
# 1661       chosen
# 1662       chosen
# 1663       chosen
# 1664       chosen
# 1665       chosen
#
# [1666 rows x 12 columns]
#     block  block_trial_num  hex    entry_time     exit_time   duration  \
# 0       1               10    1  1.742152e+09  1.742152e+09   0.530089
# 1       1               10    4  1.742152e+09  1.742152e+09   0.249451
# 2       1               10    5  1.742152e+09  1.742152e+09   0.280639
# 3       1               10    7  1.742152e+09  1.742152e+09   0.187090
# 4       1               10    9  1.742152e+09  1.742152e+09   1.465551
# 5       1               10    7  1.742152e+09  1.742152e+09   1.902094
# 6       1               10    5  1.742152e+09  1.742152e+09   0.249450
# 7       1               10    4  1.742152e+09  1.742152e+09   0.249451
# 8       1               10    1  1.742152e+09  1.742152e+09  13.564172
# 9       1               10    4  1.742152e+09  1.742152e+09   0.249470
# 10      1               10    6  1.742152e+09  1.742152e+09   0.374187
# 11      1               10    8  1.742152e+09  1.742152e+09   0.124715
# 12      1               10   11  1.742152e+09  1.742152e+09   0.155904
# 13      1               10   14  1.742152e+09  1.742152e+09   0.124735
# 14      1               10   17  1.742152e+09  1.742152e+09   0.124735
# 15      1               10   13  1.742152e+09  1.742152e+09   0.187093
# 16      1               10   16  1.742152e+09  1.742152e+09   0.280638
# 17      1               10   20  1.742152e+09  1.742152e+09   0.093546
# 18      1               10   24  1.742152e+09  1.742152e+09   0.530089
# 19      1               10   19  1.742152e+09  1.742152e+09   0.623635
# 20      1               10   23  1.742152e+09  1.742152e+09   0.467733
# 21      1               10   19  1.742152e+09  1.742152e+09   0.498920
# 22      1               10   24  1.742152e+09  1.742152e+09   0.093546
# 23      1               10   29  1.742152e+09  1.742152e+09   0.342997
# 24      1               10   35  1.742152e+09  1.742152e+09   0.155904
# 25      1               10   40  1.742152e+09  1.742152e+09   0.187093
# 26      1               10   44  1.742152e+09  1.742152e+09   0.249470
# 27      1               10   39  1.742152e+09  1.742152e+09   0.187093
# 28      1               10   43  1.742152e+09  1.742152e+09   0.311828
# 29      1               10   48  1.742152e+09  1.742152e+09   0.124735
# 30      1               10    3  1.742152e+09  1.742152e+09   1.434361
#
#     hex_in_trial  hex_entry_num  hexes_from_start  hexes_from_end  \
# 0              1              1                 0              18
# 1              2              1                 1              17
# 2              3              1                 2              18
# 3              4              1                 3              19
# 4              5              1                 4              20
# 5              6              2                 3              19
# 6              7              2                 2              18
# 7              8              2                 1              17
# 8              9              2                 0              18
# 9             10              3                 1              17
# 10            11              1                 2              16
# 11            12              1                 3              15
# 12            13              1                 4              14
# 13            14              1                 5              13
# 14            15              1                 6              12
# 15            16              1                 7              11
# 16            17              1                 8              10
# 17            18              1                 9               9
# 18            19              1                10               8
# 19            20              1                11               9
# 20            21              1                12              10
# 21            22              2                11               9
# 22            23              2                10               8
# 23            24              1                11               7
# 24            25              1                12               6
# 25            26              1                13               5
# 26            27              1                14               4
# 27            28              1                15               3
# 28            29              1                16               2
# 29            30              1                17               1
# 30            31              1                18               0
#
#         hex_type  maze_portion
# 0        optimal         start
# 1        optimal         start
# 2       dead_end         start
# 3       dead_end         start
# 4       dead_end         start
# 5       dead_end         start
# 6       dead_end         start
# 7        optimal         start
# 8        optimal         start
# 9        optimal         start
# 10       optimal         start
# 11       optimal         start
# 12       optimal         start
# 13       optimal         start
# 14       optimal         start
# 15       optimal         start
# 16       optimal         start
# 17       optimal         start
# 18       optimal         start
# 19      dead_end         start
# 20      dead_end         start
# 21      dead_end         start
# 22       optimal         start
# 23       optimal         start
# 24  choice_point  choice_point
# 25       optimal        chosen
# 26       optimal        chosen
# 27       optimal        chosen
# 28       optimal        chosen
# 29       optimal        chosen
# 30       optimal        chosen
#      block  block_trial_num  hex    entry_time     exit_time   duration  \
# 0        1                1    1  1.742151e+09  1.742151e+09   1.403194
# 1        1                1   38  1.742151e+09  1.742151e+09   0.374185
# 2        1                1   49  1.742151e+09  1.742151e+09   0.249450
# 3        1                1    2  1.742151e+09  1.742151e+09   6.641766
# 4        1                2    2  1.742151e+09  1.742151e+09  17.586658
# ..     ...              ...  ...           ...           ...        ...
# 173      3                3   44  1.742153e+09  1.742153e+09   0.311810
# 174      3                3   39  1.742153e+09  1.742153e+09   0.062357
# 175      3                3   43  1.742153e+09  1.742153e+09   0.187093
# 176      3                3   48  1.742153e+09  1.742153e+09   0.124735
# 177      3                3    3  1.742153e+09  1.742153e+09   2.151544
#
#      hex_in_trial  hex_entry_num  hexes_from_start  hexes_from_end hex_type  \
# 0               1              1                -1              22  optimal
# 1               2              1                -1               2  optimal
# 2               3              1                -1               1  optimal
# 3               4              1                -1               0  optimal
# 4               1              1                 0              22  optimal
# ..            ...            ...               ...             ...      ...
# 173            15              1                14               4  optimal
# 174            16              1                15               3  optimal
# 175            17              1                16               2  optimal
# 176            18              1                17               1  optimal
# 177            19              1                18               0  optimal
#
#     maze_portion
# 0           None
# 1         chosen
# 2         chosen
# 3         chosen
# 4          start
# ..           ...
# 173       chosen
# 174       chosen
# 175       chosen
# 176       chosen
# 177       chosen
#
# [178 rows x 12 columns]

# %% [markdown]
# Take a look at the rat's path through the hex maze for block 1, trial 10

# %%
trial_df = (HexPath & hex_path_key).fetch_trial(block=1, block_trial_num=10)
display(trial_df)
# Out:
#     block  block_trial_num  hex    entry_time     exit_time   duration  \
# 0       1               10    1  1.742152e+09  1.742152e+09   0.530089
# 1       1               10    4  1.742152e+09  1.742152e+09   0.249451
# 2       1               10    5  1.742152e+09  1.742152e+09   0.280639
# 3       1               10    7  1.742152e+09  1.742152e+09   0.187090
# 4       1               10    9  1.742152e+09  1.742152e+09   1.465551
# 5       1               10    7  1.742152e+09  1.742152e+09   1.902094
# 6       1               10    5  1.742152e+09  1.742152e+09   0.249450
# 7       1               10    4  1.742152e+09  1.742152e+09   0.249451
# 8       1               10    1  1.742152e+09  1.742152e+09  13.564172
# 9       1               10    4  1.742152e+09  1.742152e+09   0.249470
# 10      1               10    6  1.742152e+09  1.742152e+09   0.374187
# 11      1               10    8  1.742152e+09  1.742152e+09   0.124715
# 12      1               10   11  1.742152e+09  1.742152e+09   0.155904
# 13      1               10   14  1.742152e+09  1.742152e+09   0.124735
# 14      1               10   17  1.742152e+09  1.742152e+09   0.124735
# 15      1               10   13  1.742152e+09  1.742152e+09   0.187093
# 16      1               10   16  1.742152e+09  1.742152e+09   0.280638
# 17      1               10   20  1.742152e+09  1.742152e+09   0.093546
# 18      1               10   24  1.742152e+09  1.742152e+09   0.530089
# 19      1               10   19  1.742152e+09  1.742152e+09   0.623635
# 20      1               10   23  1.742152e+09  1.742152e+09   0.467733
# 21      1               10   19  1.742152e+09  1.742152e+09   0.498920
# 22      1               10   24  1.742152e+09  1.742152e+09   0.093546
# 23      1               10   29  1.742152e+09  1.742152e+09   0.342997
# 24      1               10   35  1.742152e+09  1.742152e+09   0.155904
# 25      1               10   40  1.742152e+09  1.742152e+09   0.187093
# 26      1               10   44  1.742152e+09  1.742152e+09   0.249470
# 27      1               10   39  1.742152e+09  1.742152e+09   0.187093
# 28      1               10   43  1.742152e+09  1.742152e+09   0.311828
# 29      1               10   48  1.742152e+09  1.742152e+09   0.124735
# 30      1               10    3  1.742152e+09  1.742152e+09   1.434361
#
#     hex_in_trial  hex_entry_num  hexes_from_start  hexes_from_end  \
# 0              1              1                 0              18
# 1              2              1                 1              17
# 2              3              1                 2              18
# 3              4              1                 3              19
# 4              5              1                 4              20
# 5              6              2                 3              19
# 6              7              2                 2              18
# 7              8              2                 1              17
# 8              9              2                 0              18
# 9             10              3                 1              17
# 10            11              1                 2              16
# 11            12              1                 3              15
# 12            13              1                 4              14
# 13            14              1                 5              13
# 14            15              1                 6              12
# 15            16              1                 7              11
# 16            17              1                 8              10
# 17            18              1                 9               9
# 18            19              1                10               8
# 19            20              1                11               9
# 20            21              1                12              10
# 21            22              2                11               9
# 22            23              2                10               8
# 23            24              1                11               7
# 24            25              1                12               6
# 25            26              1                13               5
# 26            27              1                14               4
# 27            28              1                15               3
# 28            29              1                16               2
# 29            30              1                17               1
# 30            31              1                18               0
#
#         hex_type  maze_portion
# 0        optimal         start
# 1        optimal         start
# 2       dead_end         start
# 3       dead_end         start
# 4       dead_end         start
# 5       dead_end         start
# 6       dead_end         start
# 7        optimal         start
# 8        optimal         start
# 9        optimal         start
# 10       optimal         start
# 11       optimal         start
# 12       optimal         start
# 13       optimal         start
# 14       optimal         start
# 15       optimal         start
# 16       optimal         start
# 17       optimal         start
# 18       optimal         start
# 19      dead_end         start
# 20      dead_end         start
# 21      dead_end         start
# 22       optimal         start
# 23       optimal         start
# 24  choice_point  choice_point
# 25       optimal        chosen
# 26       optimal        chosen
# 27       optimal        chosen
# 28       optimal        chosen
# 29       optimal        chosen
# 30       optimal        chosen

# %% [markdown]
# ## Fetch hex position data

# %%
from hex_maze_behavior import HexPosition

pos_key = {
    'pos_merge_id': '73546f6a-c60f-09f3-0c22-c5e44b3259de', 
    'nwb_file_name': 'Toby20250316_.nwb', 
    'epoch': 7
}

display(HexPosition() & pos_key)

# Fetch rat's position + assigned hex
hex_and_pos_df = (HexPosition() & pos_key).fetch_hex_and_position_dataframe()
display(hex_and_pos_df)
# Out:
# *pos_merge_id  *nwb_file_name *epoch    analysis_file_ hex_assignment
# +------------+ +------------+ +-------+ +------------+ +------------+
# 73546f6a-c60f- Toby20250316_. 7         Toby20250316_5 095e360c-ee0c-
#  (Total: 1)
# [00:36:52][WARNING] Spyglass: Upsampled position data, frame indices are invalid. Setting add_frame_ind=False
#               position_x  position_y  orientation  velocity_x  velocity_y  \
# time
# 1.742172e+09   62.041250   103.87250    -0.366782   38.442561  -29.824666
# 1.742172e+09   62.210588   103.72000    -0.365368   38.766769  -29.891796
# 1.742172e+09   62.301176   103.64000    -0.363602   39.087138  -29.952861
# 1.742172e+09   62.391765   103.56000    -0.361809   39.403551  -30.007786
# 1.742172e+09   62.482353   103.48000    -0.360012   39.715893  -30.056504
# ...                  ...         ...          ...         ...         ...
# 1.742175e+09  102.712500    14.82250    -1.043486   -2.234870    3.962956
# 1.742175e+09  102.711250    14.82625    -1.042798   -2.308990    3.994647
# 1.742175e+09  102.710000    14.83000    -1.042106   -2.383619    4.026486
# 1.742175e+09  102.708750    14.83375    -1.041409   -2.458744    4.058477
# 1.742175e+09  102.707500    14.83750    -1.040708   -2.534353    4.090625
#
#                   speed  hex hex_including_sides  distance_from_centroid
# time
# 1.742172e+09  48.655331   44                  44                2.774555
# 1.742172e+09  48.952853   44                  44                2.548839
# 1.742172e+09  49.244068   44                  44                2.429481
# 1.742172e+09  49.528851   44                  44                2.310278
# 1.742172e+09  49.807083   44                  44                2.191257
# ...                 ...  ...                 ...                     ...
# 1.742175e+09   4.549688    2                   2               10.787333
# 1.742175e+09   4.613961    2                   2               10.784237
# 1.742175e+09   4.679127    2                   2               10.781141
# 1.742175e+09   4.745172    2                   2               10.778046
# 1.742175e+09   4.812085    2                   2               10.774951
#
# [1371100 rows x 9 columns]

# %% [markdown]
# ## Fetch decoded hex position data

# %%
from hex_maze_decoding import DecodedHexPosition

decoded_pos_key = {
    'decoding_merge_id': 'f40538a7-c27c-1672-f64d-a027bfb0205f', 
    'nwb_file_name': 'Toby20250316_.nwb', 
    'epoch': 7
}

display(DecodedHexPosition() & decoded_pos_key)

# Fetch rat's decoded position + assigned hex
decoded_hex_and_pos_df = (DecodedHexPosition() & decoded_pos_key).fetch_hex_and_position_dataframe()
display(decoded_hex_and_pos_df)

# %% [markdown]
# ## Fetch and combine position and decoded position tables

# %%
from hex_maze_decoding import DecodedHexPositionSelection, DecodedHexPosition

decoded_pos_key = {
    'decoding_merge_id': 'f40538a7-c27c-1672-f64d-a027bfb0205f', 
    'nwb_file_name': 'Toby20250316_.nwb', 
    'epoch': 7
}

keys = (HexPosition & decoded_pos_key).fetch("KEY")
print(keys)

# TODO: Be able to find the position key that corresponds to the upsampled one used for decoding
# so I can automate fetching a combined dataframe here. There is probably a long range restriction for that.

position_df = (HexPosition & keys[1]).fetch_hex_and_position_dataframe()
display(position_df)

decode_df = (DecodedHexPosition & decoded_pos_key).fetch_hex_and_position_dataframe()
decode_df.columns = [f"decode_{col}" for col in decode_df.columns]
display(decode_df)

combined_df = position_df.join(decode_df)
display(combined_df)
